# %% [markdown]
# <a href="https://colab.research.google.com/github/Emadamx/White-box-activation-steering/blob/main/white_box.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !rm -rf white-box-activation-steering

# %%
# !git clone https://github.com/Emadamx/white-box-activation-steering.git
# Out:
# Cloning into 'white-box-activation-steering'...
# remote: Enumerating objects: 33, done.
# remote: Counting objects: 100% (33/33), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 33 (delta 3), reused 33 (delta 3), pack-reused 0 (from 0)
# Receiving objects: 100% (33/33), 23.16 KiB | 2.89 MiB/s, done.
# Resolving deltas: 100% (3/3), done.

# %%
# %cd white-box-activation-steering
# Out:
# /content/white-box-activation-steering/white-box-activation-steering

# %%
# !pip install -e .
# Out:
# Obtaining file:///content/white-box-activation-steering/white-box-activation-steering
#   Preparing metadata (setup.py) ... done
# ...
#   Attempting uninstall: white-box-activation-steering
#     Found existing installation: white-box-activation-steering 0.1.0
#     Uninstalling white-box-activation-steering-0.1.0:
#       Successfully uninstalled white-box-activation-steering-0.1.0
#   Running setup.py develop for white-box-activation-steering
# ...

# %% [markdown]
# ## Running the experiments

# %%
# %run experiments/01_probe_layer_selection.py --config configs/default.yaml
# Out:
# No checkpoint found — using randomly initialised agent (for testing).
# ...
# Training linear deception probes at each layer...
# Layer-wise deception probe accuracy:
#   Layer  0: 0.680 ← best
#   Layer  1: 0.680
#   Layer  2: 0.680
#   Layer  3: 0.680
#
# Best layer: l* = 0 (accuracy=0.680)
# Saved plot to results/exp01/probe_accuracy_curve.png

# %%
# Experiment 02
# %run experiments/02_direction_learning.py --config configs/default.yaml --method lp
# Out:
# Using l* = 0 from Experiment 01 results.
# ...
# Learning direction with method='lp'...
# Direction shape: (64,)
# Direction norm: 1.0000 (should be 1.0)
# Linear probe train accuracy: 0.780
# Saved direction to results/exp02/direction_lp_layer0.pt

# %%
# Experiment 03
# %run experiments/03_steering_evaluation.py --config configs/default.yaml
# Out:
# Auto-detected l* = 0 from Experiment 01 results.
# No checkpoint — using randomly initialised agent (for testing).
#
# Evaluating baseline (no intervention)...
#   Deception rate: 53.00%
#   Mean reward:    1.820
#
# Evaluating steering (method=lp, layer=0)...
#   α=0.0 | Deception: 52.00% | Perf retained: 101.10%
#   α=0.2 | Deception: 54.00% | Perf retained: 101.37%
#   α=0.4 | Deception: 49.50% | Perf retained: 93.68%
#   α=0.6 | Deception: 48.50% | Perf retained: 103.30%
#   α=0.8 | Deception: 44.00% | Perf retained: 102.20%
#   α=1.0 | Deception: 56.00% | Perf retained: 91.76%
#
# Direction file not found: results/exp02/direction_dom_layer0.pt — skipping dom
#
# Results saved to results/exp03/results.json
# Saved safety-utility frontier plot to results/exp03/safety_utility_frontier.png
#
# ...
# SUMMARY
# ...
# Condition                  Deception Rate Perf Retained
# -------------------------------------------------------
# No intervention                   53.00%       100.00%
# ...
